# %%
import os

print(os.getcwd())
os.chdir("..")
print(os.getcwd())
# Out:
# c:\Users\dzmitry\Desktop\Network_security_project\notebooks
# c:\Users\dzmitry\Desktop\Network_security_project

# %%
from networksecurity.constants.training_pipeline import SCHEMA_FILE_PATH
from networksecurity.utils.main_utils.utils import read_yaml_file,write_yaml_file

# %%
a=read_yaml_file(SCHEMA_FILE_PATH)

# %%
import pandas as pd
a=pd.DataFrame(
{'a':[1,2,3],'b':[4,5,6],'c':['a','b','c']}
)

# %%
b=pd.DataFrame(
{'a':[1,2,30],'b':[4,5,60],'c':['a','b','c']}
)

# %%
for column in a.columns:
    d1=a[column]
    d2=b[column]
d2
# Out:
# 0    a
# 1    b
# 2    c
# Name: c, dtype: object

# %%
d1
# Out:
# 0    a
# 1    b
# 2    c
# Name: c, dtype: object
